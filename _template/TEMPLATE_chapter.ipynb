# %% [markdown]
# # Chapter MM-CC · <Title: the one idea, in plain words>
#
# **Label:** Core / Applied / Optional  |  **Time:** ~NN minutes  |  **Difficulty:** gentle / moderate / demanding
#
# **Prerequisites:** <chapter ids and what the learner must already be able to do>
#
# **Position in the learning path:** module MM (<module name>), chapter CC of NN. Before this: <id>. After this: <id>.
#
# ---
#
# ## Why this matters
#
# <Two or three sentences. A situation the learner will actually meet - an exam question, an
# interview question, a bug, a decision at work - that this chapter makes answerable. No
# motivation-by-hype.>
#
# ## What you will be able to do
#
# By the end of this chapter you can:
#
# 1. <measurable verb: state / compute / implement / diagnose / choose / justify> ...
# 2. ...
# 3. ...
# 4. ...
# 5. ...

# %% [markdown]
# ## Warm-up: what you already know
#
# <3-5 retrieval questions from EARLIER chapters, answered from memory before scrolling.
# Retrieval, not re-reading, is what makes earlier material stick. Give the answers a few
# lines below so the learner can check immediately.>

# %% [markdown]
# ## The situation
#
# <A familiar human story. A person, a decision, a cost of being wrong. No dataset yet, no
# notation, no library names.>
#
# **The question this chapter answers:** <one sentence, in the story's own words>

# %%
# The tiny table: 3-10 rows, typed by hand so every number can be checked by hand.
# Illustration only - not real data, no conclusion about the world is drawn from it.

# %% [markdown]
# ### Predict before running
#
# Write your answers down before you run the next cell. Being wrong on purpose is the
# fastest way to learn.
#
# 1. <question about what the output will look like>
# 2. <question about direction: bigger or smaller? which one wins?>
# 3. <question that a common misconception would get wrong>

# %%
# Visual intuition: one picture of the idea. Axes labelled with units, title, legend.

# %% [markdown]
# ## The intuition, in ordinary language
#
# <The idea with no symbols at all. Analogy allowed - and immediately say where the analogy
# stops being true.>

# %% [markdown]
# ## The maths, slowly
#
# **The question the formula answers:** <one sentence>
#
# **With real numbers first:**
#
# <Work one example by hand, showing every arithmetic step and the units.>
#
# **Now the symbols:**
#
# <formula>
#
# where <define every symbol, its units, and its array shape if it has one>.
#
# **Back to English:** <read the formula aloud as a sentence>
#
# **Assumptions:** <when this is the right thing to compute, and when it is not>

# %%
# From scratch: the essential mechanism in a few lines, no library shortcut.
# Do not hide the concept being taught inside a helper function.

# %%
# The standard library version - and a check that it gives the same answer as the
# from-scratch version. The library is a faster hand, not a different idea.

# %% [markdown]
# ## On realistic data
#
# <Say which dataset, why it is appropriate, and what one row is. If synthetic, say SYNTHETIC
# and say what property was built into it on purpose.>

# %%
# Realistic application, including the baseline it must beat.

# %%
# Diagnostics: not one number. Error by segment, residuals, or a curve.

# %% [markdown]
# ## Failure lab: what can go wrong
#
# <Break it on purpose. Show the wrong result first, before explaining it.>

# %%
# The failure, reproduced.

# %% [markdown]
# ### Diagnosis
#
# <Why it failed, in terms of the mechanism taught above - not "the model is bad".>
#
# ### Realistic remedies, compared
#
# | Remedy | What it fixes | What it costs | When to prefer it |
# |---|---|---|---|
# | | | | |

# %% [markdown]
# ## Common misconceptions
#
# **"<misconception, stated the way people actually say it>"**
# <Why it is wrong, and the smallest example that shows it.>

# %% [markdown]
# ## Exercises
#
# Do these before opening the solutions. The solutions explain reasoning, so they are worth
# reading even when you got the answer right: `solutions/<module>/<file>_solutions.ipynb`.
#
# ### Quick understanding
# ### Hand calculation
# ### Coding
# ### Interpretation
# ### Debugging
# ### Exam and interview reasoning
# ### Transfer to a different situation
# ### Explain it to someone non-technical
# ### Optional challenge

# %% [markdown]
# ## Mastery check
#
# Can you, without looking:
#
# - [ ] ...
# - [ ] ...
# - [ ] ...
#
# If any box stays unticked, the section to reread is named next to it.

# %% [markdown]
# ## What should now feel instinctive
#
# <3-5 reflexes, phrased as things the learner now does automatically when they meet a new
# problem.>

# %% [markdown]
# ## Flashcards
#
# | Question | Answer |
# |---|---|
# | | |

# %% [markdown]
# ## Next
#
# **Chapter MM-CC · <next title>** - <one sentence on the question it opens, and how this
# chapter set it up.>
#
# New terms from this chapter are in [GLOSSARY.md](../../GLOSSARY.md).
